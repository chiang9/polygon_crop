# %%
from polygon_crop.img_crop import *
from PIL import Image
from IPython.display import display
import numpy

# %% [markdown]
# # Crop Image Interactively
# With **img_crop**, we are able to crop image **interactively**.
#
# **img_crop** simply takes the image numpy array.

# %%
path = 'Data/rabbit.jpeg'
ip = img_processing()
img = Image.open(path).convert("RGB")
img_array = numpy.asarray(img)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=847x492 at 0x28543588D30>

# %%
newIm = ip.img_crop(img_array)
# Out:
# Press ESC to exit the edit mode
# click on x: 242 y: 10
# click on x: 157 y: 24
# click on x: 154 y: 269
# click on x: 249 y: 268
# click on x: 314 y: 205
# click on x: 318 y: 126
# click on x: 272 y: 66
# click on x: 273 y: 8

# %%
img = Image.fromarray(newIm, 'RGB')
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=847x492 at 0x285435755C0>
